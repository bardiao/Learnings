# %%
import pandas as pd

# %%
train = pd.read_csv("C:\\Users\LENOVO\\Desktop\\quera ex5\\diamond\\data\\diamonds_train.csv")
train
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22004\3361595819.py:1: SyntaxWarning: invalid escape sequence '\L'
#   train = pd.read_csv("C:\\Users\LENOVO\\Desktop\\quera ex5\\diamond\\data\\diamonds_train.csv")
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# ...

# %%
test = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\quera ex5\\diamond\\data\\diamonds_test.csv")
test
# Out:
#       carat        cut color clarity  depth  table     x     y     z
# 0      0.73      Ideal     G    VVS2   61.9   55.0  5.83  5.77  3.59
# 1      0.61    Premium     F    VVS2   59.7   58.0  5.56  5.53  3.31
# 2      1.55    Premium     I     VS1   58.2   60.0  7.69  7.59  4.45
# 3      0.46       Good     F      IF   56.2   61.0  5.16  5.24  2.92
# 4      1.10  Very Good     F     VS2   60.6   58.0  6.67  6.77  4.07
# ...     ...        ...   ...     ...    ...    ...   ...   ...   ...
# 3935   1.58    Premium     I     VS1   61.1   59.0  7.52  7.44  4.57
# 3936   1.00  Very Good     F     SI1   63.1   59.0  6.29  6.22  3.95
# 3937   1.13    Premium     H     VS1   58.9   58.0  6.81  6.78  4.00
# 3938   1.51      Ideal     E     VS2   62.8   56.0  7.31  7.24  4.57
# 3939   1.55      Ideal     G     SI2   60.7   55.0  7.54  7.51  4.57
#
# [3940 rows x 9 columns]

# %%
train.value_counts()
# Out:
# carat  cut      color  clarity  depth  table  price  x      y      z
# 0.79   Ideal    G      SI1      62.3   57.0   2898   5.90   5.85   3.66    5
# 0.32   Ideal    H      VVS2     61.8   55.0   828    4.42   4.38   2.72    2
# 0.60   Premium  D      SI2      62.0   57.0   1196   5.43   5.35   3.34    2
# 0.31   Ideal    H      VVS1     61.6   55.0   687    4.37   4.40   2.70    2
# 0.35   Ideal    F      VS2      61.4   54.0   706    4.54   4.58   2.80    2
#                                                                           ..
# 4.01   Premium  I      I1       61.0   61.0   15223  10.14  10.10  6.17    1
#                 J      I1       62.5   62.0   15223  10.02  9.94   6.24    1
# 4.13   Fair     H      I1       64.8   61.0   17329  10.00  9.85   6.43    1
# 4.50   Fair     J      I1       65.8   58.0   18531  10.23  10.16  6.72    1
# 0.20   Ideal    E      VS2      62.2   57.0   367    3.76   3.73   2.33    1
# Name: count, Length: 49874, dtype: int64

# %%
train.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
train['cut'] = label_encoder.fit_transform(train['cut'])
train['color'] = label_encoder.fit_transform(train['color'])
train['clarity'] = label_encoder.fit_transform(train['clarity'])
train
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
train.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
x_train = train.drop(columns=['price'])
y_train = train['price']
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x_train)
r2_score(y_train, y_pred)
# Out:
# 0.885378671560266

# %%
label_encoder = LabelEncoder()
test['cut'] = label_encoder.fit_transform(test['cut'])
test['color'] = label_encoder.fit_transform(test['color'])
test['clarity'] = label_encoder.fit_transform(test['clarity'])
test
# Out:
#       carat  cut  color  clarity  depth  table     x     y     z
# 0      0.73    2      3        7   61.9   55.0  5.83  5.77  3.59
# 1      0.61    3      2        7   59.7   58.0  5.56  5.53  3.31
# 2      1.55    3      5        4   58.2   60.0  7.69  7.59  4.45
# 3      0.46    1      2        1   56.2   61.0  5.16  5.24  2.92
# 4      1.10    4      2        5   60.6   58.0  6.67  6.77  4.07
# ...     ...  ...    ...      ...    ...    ...   ...   ...   ...
# 3935   1.58    3      5        4   61.1   59.0  7.52  7.44  4.57
# 3936   1.00    4      2        2   63.1   59.0  6.29  6.22  3.95
# 3937   1.13    3      4        4   58.9   58.0  6.81  6.78  4.00
# 3938   1.51    2      1        5   62.8   56.0  7.31  7.24  4.57
# 3939   1.55    2      3        3   60.7   55.0  7.54  7.51  4.57
#
# [3940 rows x 9 columns]

# %%
x_test = test
y_test_pred = model.predict(x_test)

# %%
submission = pd.DataFrame({'price': y_test_pred})

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
joblib.dump(model, 'model')
file_names = ['diamond.ipynb', 'submission.csv', 'model']
compress(file_names)
# Out:
# File Paths:
# ['diamond.ipynb', 'submission.csv', 'model']
